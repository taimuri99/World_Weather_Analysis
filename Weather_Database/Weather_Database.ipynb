# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
cities
# Out:
# ['busselton',
#  'bluff',
#  'batemans bay',
#  'nurota',
#  'cumra',
#  'longyearbyen',
#  'coquimbo',
#  'barrow',
#  'mataura',
#  'naqadeh',
#  'hermanus',
#  'thompson',
#  'rikitea',
#  'amderma',
#  'bredasdorp',
#  'labuan',
#  'lorengau',
#  'mount gambier',
#  'puerto ayora',
#  'henties bay',
#  'illoqqortoormiut',
#  'hihifo',
#  'clyde river',
#  'chicama',
#  'tabiauea',
#  'lebu',
#  'halalo',
#  'tasiilaq',
#  'nikolskoye',
#  'saldanha',
#  'kaitangata',
#  'kodiak',
#  'carutapera',
#  'husavik',
#  'barra da estiva',
#  'jamestown',
#  'mazyr',
#  'avarua',
#  'vila franca do campo',
#  'kapaa',
#  'mahebourg',
#  'cobija',
#  'tuktoyaktuk',
#  'albany',
#  'kavieng',
#  'asyut',
#  'san policarpo',
#  'isangel',
#  'new norfolk',
#  'port elizabeth',
#  'blagoyevo',
#  'shenjiamen',
#  'ust-tsilma',
#  'mizan teferi',
#  'cape town',
#  'challapata',
#  'dikson',
#  'pevek',
#  'olafsvik',
#  'batagay-alyta',
#  'dingle',
#  'guadalupe',
#  'hobart',
#  'lompoc',
#  'karaul',
#  'mutis',
#  'kirkwall',
#  'meulaboh',
#  'sorvag',
#  'bathsheba',
#  'punta arenas',
#  'grand river south east',
#  'dali',
#  'la cruz',
#  'la orilla',
#  'makakilo city',
#  'zhigansk',
#  'ushuaia',
#  'taolanaro',
#  'arraial do cabo',
#  'hilo',
#  'kurud',
#  'sinnamary',
#  'rungata',
#  'provideniya',
#  'cidreira',
#  'slave lake',
#  'torbay',
#  'vaini',
#  'biak',
#  'chokurdakh',
#  'maragogi',
#  'khonuu',
#  'fort nelson',
#  'atasu',
#  'fortuna',
#  'palmer',
#  'port lincoln',
#  'butaritari',
#  'svetlyy',
#  'cururupu',
#  'souris',
#  'elmadag',
#  'lubango',
#  'maldonado',
#  'hithadhoo',
#  'novi pazar',
#  'khatanga',
#  'alexandria',
#  'airai',
#  'sorland',
#  'kruisfontein',
#  'mankato',
#  'erenhot',
#  'seydi',
#  'tuensang',
#  'sobolevo',
#  'erzin',
#  'iqaluit',
#  'zawiercie',
#  'taoudenni',
#  'carnarvon',
#  'nanortalik',
#  'borovoy',
#  'pontian kecil',
#  'cherskiy',
#  'saint-philippe',
#  'norman wells',
#  'sinkat',
#  'east london',
#  'marabba',
#  'kamennogorsk',
#  'pakala',
#  'petropavlovsk-kamchatskiy',
#  'padang',
#  'namatanai',
#  'port alfred',
#  'vostok',
#  'atuona',
#  'devils lake',
#  'thunder bay',
#  'columbia',
#  'salina',
#  'sorsk',
#  'harper',
#  'alyangula',
#  'pangnirtung',
#  'clinton',
#  'katsuura',
#  'upernavik',
#  'saskylakh',
#  'dwarka',
#  'victoria',
#  'naze',
#  'jacmel',
#  'tel aviv-yafo',
#  'cayenne',
#  'nishihara',
#  'saint-augustin',
#  'varkaus',
#  'camacha',
#  'northam',
#  'kirakira',
#  'yellowknife',
#  'kavaratti',
#  'esna',
#  'maniitsoq',
#  'thyolo',
#  'praia da vitoria',
#  'chapais',
#  'mar del plata',
#  'puerto quijarro',
#  'qaanaaq',
#  'lososina',
#  'bairiki',
#  'merauke',
#  'katherine',
#  'bontang',
#  'malumfashi',
#  'severomorsk',
#  'biggar',
#  'ancud',
#  'talnakh',
#  'ribeira grande',
#  'ruidoso',
#  'severo-kurilsk',
#  'lincoln',
#  'samalaeulu',
#  'road town',
#  'arman',
#  'pakruojis',
#  'antsohihy',
#  'kamenskoye',
#  'taburi',
#  'tiksi',
#  'roches noires',
#  'saint george',
#  'vila velha',
#  'yar-sale',
#  'barentsburg',
#  'ilulissat',
#  'kahului',
#  'maravilha',
#  'ambulu',
#  'horasan',
#  'belushya guba',
#  'willmar',
#  'lermontovka',
#  'estelle',
#  'aswan',
#  'hualmay',
#  'qasigiannguit',
#  'vaitupu',
#  'ereymentau',
#  'nizhneyansk',
#  'chivay',
#  'jieshi',
#  'poum',
#  'caorle',
#  'karratha',
#  'guerrero negro',
#  'obera',
#  'darhan',
#  'kijabe',
#  'marcona',
#  'ulladulla',
#  'lata',
#  'sitka',
#  'bilibino',
#  'yarada',
#  'kaseda',
#  'korla',
#  'salalah',
#  'papara',
#  'daru',
#  'moose factory',
#  'haines junction',
#  'yacuiba',
#  'pisco',
#  'mucuri',
#  'takanabe',
#  'castro',
#  'college',
#  'port moresby',
#  'atar',
#  'berlevag',
#  'luderitz',
#  'seymchan',
#  'mecca',
#  'los llanos de aridane',
#  'lolua',
#  'kampene',
#  'muros',
#  'barzas',
#  'nongstoin',
#  'georgetown',
#  'ulaangom',
#  'ponta do sol',
#  'noumea',
#  'alice springs',
#  'tautira',
#  'del rio',
#  'khash',
#  'palabuhanratu',
#  'narsaq',
#  'carandai',
#  'buraydah',
#  'ahipara',
#  'calama',
#  'rocha',
#  'boone',
#  'darnah',
#  'igrim',
#  'bichena',
#  'guaraniacu',
#  'tamandare',
#  'sisimiut',
#  'bogorodskoye',
#  'laguna',
#  'lagoa',
#  'kawalu',
#  'mino',
#  'terra santa',
#  'aklavik',
#  'mennecy',
#  'sataua',
#  'staroye drozhzhanoye',
#  'udachnyy',
#  'lichinga',
#  'itaituba',
#  'brownsville',
#  'ginir',
#  'moanda',
#  'takaungu',
#  'samarai',
#  'port blair',
#  'isiro',
#  'pimenta bueno',
#  'kudahuvadhoo',
#  'lanxi',
#  'lulea',
#  'orasac',
#  'lazaro cardenas',
#  'asau',
#  'broken hill',
#  'vila do maio',
#  'palana',
#  'acapulco',
#  'el alto',
#  'revda',
#  'attawapiskat',
#  'antofagasta',
#  'loikaw',
#  'carauari',
#  'pareora',
#  'santa maria',
#  'samusu',
#  'pithora',
#  'muisne',
#  'acajutla',
#  'kokoda',
#  'jalu',
#  'bambous virieux',
#  'asayita',
#  'qui nhon',
#  'san patricio',
#  'ostrovnoy',
#  'kinshasa',
#  'tapes',
#  'wattegama',
#  'honningsvag',
#  'la palma',
#  'cabo san lucas',
#  'little current',
#  'kholmogory',
#  'yulara',
#  'rocky mount',
#  'eyl',
#  'tambura',
#  'cuamba',
#  'bolungarvik',
#  'ovsyanka',
#  'jasper',
#  'avera',
#  'sorong',
#  'cabatuan',
#  'nikolayevsk-na-amure',
#  'batagay',
#  'sao jose da coroa grande',
#  'vire',
#  'jining',
#  'safford',
#  'yarkovo',
#  'rawson',
#  'nuuk',
#  'esso',
#  'te anau',
#  'amudat',
#  'kashi',
#  'ust-charyshskaya pristan',
#  'rizoma',
#  'medicine hat',
#  'labutta',
#  'esperance',
#  'derzhavinsk',
#  'poso',
#  'sari',
#  'luang prabang',
#  'aksu',
#  'san quintin',
#  'lushoto',
#  'omboue',
#  'roald',
#  'kommunar',
#  'port-gentil',
#  'nyurba',
#  'touros',
#  'makambako',
#  'praxedis guerrero',
#  'kaeo',
#  'edson',
#  'bethel',
#  'bukachacha',
#  'turbat',
#  'yumen',
#  'uri',
#  'galesong',
#  'flinders',
#  'sabang',
#  'deputatskiy',
#  'macae',
#  'guanica',
#  'ewa beach',
#  'rondonopolis',
#  'shunyi',
#  'bolshiye klyuchishchi',
#  'grand gaube',
#  'bafoulabe',
#  'geraldton',
#  'vanimo',
#  'hasaki',
#  'polunochnoye',
#  'randvere',
#  'bonavista',
#  'tabas',
#  'otradnoye',
#  'mana',
#  'tiarei',
#  'nelson bay',
#  'baghdad',
#  'baykit',
#  'athabasca',
#  'crailsheim',
#  'ambilobe',
#  'brae',
#  'kirovskiy',
#  'alcaniz',
#  'half moon bay',
#  'mayo',
#  'nogent-le-rotrou',
#  'constantine',
#  'yenagoa',
#  'redwater',
#  'haftoni',
#  'hearst',
#  'russell',
#  'mason city',
#  'sao filipe',
#  'presidente medici',
#  'shimoda',
#  'derby',
#  'pozo colorado',
#  'mys shmidta',
#  'vestmannaeyjar',
#  'bay roberts',
#  'faanui',
#  'beloha',
#  'ust-omchug',
#  'maceio',
#  'vryburg',
#  'anadyr',
#  'axixa do tocantins',
#  'manono',
#  'tabuk',
#  'baruun-urt',
#  'alofi',
#  'lavrentiya',
#  'bandraboua',
#  'matao',
#  'port keats',
#  'nanakuli',
#  'nhulunbuy',
#  'shelburne',
#  'marsa matruh',
#  'gazanjyk',
#  'bukama',
#  'salekhard',
#  'orlik',
#  'havoysund',
#  'chirilagua',
#  'awjilah',
#  'manicore',
#  'vanavara',
#  'onda',
#  'ambatolampy',
#  'ferkessedougou',
#  'copiapo',
#  'doka',
#  'ailigandi',
#  'jiuquan',
#  'beinasco',
#  'olinda',
#  'atbasar',
#  'bambari',
#  'salto',
#  'evensk',
#  'kupang',
#  'wieliczka',
#  'tilichiki',
#  'oranjestad',
#  'chuy',
#  'makinsk',
#  'neuquen',
#  'worthing',
#  'teya',
#  'hamilton',
#  'banda aceh',
#  'umzimvubu',
#  'egvekinot',
#  'tumannyy',
#  'moree',
#  'canchungo',
#  'manamadurai',
#  'voi',
#  'matagami',
#  'murud',
#  'strezhevoy',
#  'matara',
#  'tarudant',
#  'bengkulu',
#  'saurimo',
#  'yangliuqing',
#  'nizhniy baskunchak',
#  'kongsberg',
#  'boden',
#  'diego de almagro',
#  'tigil',
#  'huarmey',
#  'kasongo-lunda',
#  'traralgon',
#  'malinyi',
#  'marv dasht',
#  'kalmunai',
#  'teguldet',
#  'boissevain',
#  'kalengwa',
#  'najran',
#  'srandakan',
#  'shubarshi',
#  'pelym',
#  'mitsamiouli',
#  'sentyabrskiy',
#  'sovetskiy',
#  'bristol',
#  'amapa',
#  'kloulklubed',
#  'arecibo',
#  'tuggurt',
#  'bambanglipuro',
#  'tsihombe',
#  'karamea',
#  'kamenka',
#  'mogadishu',
#  'codrington',
#  'baculin',
#  'ribeira brava',
#  'yanji',
#  'saint augustine',
#  'bansko',
#  'lesnoye',
#  'beringovskiy',
#  'novoagansk',
#  'ballina',
#  'north bend',
#  'bembereke',
#  'itarema',
#  'sibolga',
#  'kamina',
#  'the pas',
#  'mazamari',
#  'vestmanna',
#  'toliary',
#  'foca',
#  'kota tinggi',
#  'majene',
#  'savannah bight',
#  'tuatapere',
#  'dalinghe',
#  'nhlangano',
#  'praia',
#  'santiago',
#  'belaya gora',
#  'sorgun',
#  'cazaje',
#  'walvis bay',
#  'nizhniy kuranakh',
#  'byron bay',
#  'kenmare',
#  'yerbogachen',
#  'sept-iles',
#  'coro',
#  'karlskrona',
#  'ust-kulom',
#  'the valley',
#  'dhidhdhoo',
#  'dolores',
#  'wilmington',
#  'prosec',
#  'camocim',
#  'sao joao da barra',
#  'kulhudhuffushi',
#  'pochutla',
#  'powell river',
#  'assiniboia',
#  'buala',
#  'sambava',
#  'hami',
#  'koroni',
#  'krasnoselkup',
#  'troitsk',
#  'buchanan',
#  'santiago del estero',
#  'moron',
#  'caravelas',
#  'satellite beach',
#  'puerto cortes',
#  'meyungs',
#  'tambun',
#  'necochea',
#  'hobyo',
#  'acari',
#  'tiznit',
#  'srednekolymsk',
#  'sonoita',
#  'dzaoudzi',
#  'davila',
#  'linxia',
#  'lalin',
#  'macas',
#  'niamey',
#  'hailar',
#  'fare',
#  'champerico',
#  'nouadhibou',
#  'bandundu',
#  'guatire',
#  'grande prairie',
#  'pangkalanbuun',
#  'westport',
#  'gombe',
#  'safaga',
#  'bastrop',
#  'kismayo',
#  'marawi',
#  'vikulovo',
#  'talara',
#  'inyonga',
#  'rafaela',
#  'callaguip',
#  'upata',
#  'mutoko',
#  'suoyarvi',
#  'soc trang',
#  'munsingen',
#  'praya',
#  'flin flon',
#  'tawnat',
#  'adrar',
#  'mount isa',
#  'cockburn town',
#  'bubaque',
#  'tayu',
#  'buta',
#  'henzada',
#  'suntar',
#  'hofn',
#  'cap-aux-meules',
#  'smithers',
#  'tchibanga',
#  'margate',
#  'freetown',
#  'garissa',
#  'coahuayana',
#  'pires do rio',
#  'bela vista do paraiso',
#  'ambon',
#  'ngorongoro',
#  'panaba',
#  'malanville',
#  'battle creek',
#  'sao felix do xingu',
#  'nemuro',
#  'taltal',
#  'tynda',
#  'piacabucu',
#  'gobabis',
#  'hovd',
#  'saravena',
#  'pangai',
#  'klaksvik',
#  'kuching',
#  'kang',
#  'camana',
#  'opuwo',
#  'mayumba',
#  'seoul',
#  'sembe',
#  'butterworth',
#  'komsomolskiy',
#  'sur',
#  'envira',
#  'montijo',
#  'nema',
#  'leningradskiy',
#  'broome',
#  'santa rosa',
#  'gopalpur',
#  'havelock',
#  'williams lake',
#  'ejido',
#  'paamiut',
#  'somotillo',
#  'christchurch',
#  'ous',
#  'kikuchi',
#  'kayes',
#  'hun',
#  'haizhou',
#  'sabla',
#  'algodones',
#  'zhitikara',
#  'pampas',
#  'ngunguru',
#  'tutoia',
#  'longyan',
#  'uslar',
#  'baoning',
#  'irtyshskiy',
#  'champasak',
#  'khovu-aksy',
#  'riyadh',
#  'khor',
#  'glenluce',
#  'luau',
#  'vilhena',
#  'santa isabel do rio negro',
#  'pringsewu',
#  'mahibadhoo',
#  'pemangkat',
#  'kangaatsiaq',
#  'kysyl-syr',
#  'coxim',
#  'sibu',
#  'kleck',
#  'skarzysko-kamienna',
#  'yantongshan',
#  'portland',
#  'aizpute',
#  'ponta delgada',
#  'dukat',
#  'pascagoula',
#  'kieta',
#  'ishigaki',
#  'iquique',
#  'kushima',
#  'izhma',
#  'dankov']

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | batemans bay
# Processing Record 4 of Set 1 | nurota
# Processing Record 5 of Set 1 | cumra
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | coquimbo
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | naqadeh
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | labuan
# Processing Record 17 of Set 1 | lorengau
# Processing Record 18 of Set 1 | mount gambier
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | henties bay
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 1 | clyde river
# Processing Record 24 of Set 1 | chicama
# Processing Record 25 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | carutapera
# Processing Record 34 of Set 1 | husavik
# Processing Record 35 of Set 1 | barra da estiva
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | mazyr
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | cobija
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | asyut
# Processing Record 47 of Set 1 | san policarpo
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | blagoyevo
# Processing Record 2 of Set 2 | shenjiamen
# Processing Record 3 of Set 2 | ust-tsilma
# Processing Record 4 of Set 2 | mizan teferi
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | challapata
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | olafsvik
# Processing Record 10 of Set 2 | batagay-alyta
# Processing Record 11 of Set 2 | dingle
# Processing Record 12 of Set 2 | guadalupe
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | lompoc
# Processing Record 15 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 2 | mutis
# Processing Record 17 of Set 2 | kirkwall
# Processing Record 18 of Set 2 | meulaboh
# Processing Record 19 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 2 | dali
# Processing Record 24 of Set 2 | la cruz
# Processing Record 25 of Set 2 | la orilla
# Processing Record 26 of Set 2 | makakilo city
# Processing Record 27 of Set 2 | zhigansk
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | kurud
# Processing Record 33 of Set 2 | sinnamary
# Processing Record 34 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | slave lake
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | biak
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | maragogi
# Processing Record 43 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 2 | fort nelson
# Processing Record 45 of Set 2 | atasu
# Processing Record 46 of Set 2 | fortuna
# Processing Record 47 of Set 2 | palmer
# Processing Record 48 of Set 2 | port lincoln
# Processing Record 49 of Set 2 | butaritari
# Processing Record 50 of Set 2 | svetlyy
# Processing Record 1 of Set 3 | cururupu
# Processing Record 2 of Set 3 | souris
# Processing Record 3 of Set 3 | elmadag
# Processing Record 4 of Set 3 | lubango
# Processing Record 5 of Set 3 | maldonado
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | novi pazar
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | alexandria
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | sorland
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | mankato
# Processing Record 14 of Set 3 | erenhot
# Processing Record 15 of Set 3 | seydi
# Processing Record 16 of Set 3 | tuensang
# Processing Record 17 of Set 3 | sobolevo
# Processing Record 18 of Set 3 | erzin
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | zawiercie
# Processing Record 21 of Set 3 | taoudenni
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | borovoy
# Processing Record 25 of Set 3 | pontian kecil
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | saint-philippe
# Processing Record 28 of Set 3 | norman wells
# Processing Record 29 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | marabba
# Processing Record 32 of Set 3 | kamennogorsk
# Processing Record 33 of Set 3 | pakala
# Processing Record 34 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 3 | padang
# Processing Record 36 of Set 3 | namatanai
# Processing Record 37 of Set 3 | port alfred
# Processing Record 38 of Set 3 | vostok
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | devils lake
# Processing Record 41 of Set 3 | thunder bay
# Processing Record 42 of Set 3 | columbia
# Processing Record 43 of Set 3 | salina
# Processing Record 44 of Set 3 | sorsk
# Processing Record 45 of Set 3 | harper
# Processing Record 46 of Set 3 | alyangula
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | clinton
# Processing Record 49 of Set 3 | katsuura
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | dwarka
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | naze
# Processing Record 5 of Set 4 | jacmel
# Processing Record 6 of Set 4 | tel aviv-yafo
# Processing Record 7 of Set 4 | cayenne
# Processing Record 8 of Set 4 | nishihara
# Processing Record 9 of Set 4 | saint-augustin
# Processing Record 10 of Set 4 | varkaus
# Processing Record 11 of Set 4 | camacha
# Processing Record 12 of Set 4 | northam
# Processing Record 13 of Set 4 | kirakira
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | kavaratti
# Processing Record 16 of Set 4 | esna
# Processing Record 17 of Set 4 | maniitsoq
# Processing Record 18 of Set 4 | thyolo
# Processing Record 19 of Set 4 | praia da vitoria
# Processing Record 20 of Set 4 | chapais
# Processing Record 21 of Set 4 | mar del plata
# Processing Record 22 of Set 4 | puerto quijarro
# Processing Record 23 of Set 4 | qaanaaq
# Processing Record 24 of Set 4 | lososina
# Processing Record 25 of Set 4 | bairiki
# Processing Record 26 of Set 4 | merauke
# Processing Record 27 of Set 4 | katherine
# Processing Record 28 of Set 4 | bontang
# Processing Record 29 of Set 4 | malumfashi
# Processing Record 30 of Set 4 | severomorsk
# Processing Record 31 of Set 4 | biggar
# Processing Record 32 of Set 4 | ancud
# Processing Record 33 of Set 4 | talnakh
# Processing Record 34 of Set 4 | ribeira grande
# Processing Record 35 of Set 4 | ruidoso
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | lincoln
# Processing Record 38 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 4 | road town
# Processing Record 40 of Set 4 | arman
# Processing Record 41 of Set 4 | pakruojis
# Processing Record 42 of Set 4 | antsohihy
# Processing Record 43 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 45 of Set 4 | tiksi
# Processing Record 46 of Set 4 | roches noires
# City not found. Skipping...
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | vila velha
# Processing Record 49 of Set 4 | yar-sale
# Processing Record 50 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 5 | ilulissat
# Processing Record 2 of Set 5 | kahului
# Processing Record 3 of Set 5 | maravilha
# Processing Record 4 of Set 5 | ambulu
# Processing Record 5 of Set 5 | horasan
# Processing Record 6 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 5 | willmar
# Processing Record 8 of Set 5 | lermontovka
# Processing Record 9 of Set 5 | estelle
# Processing Record 10 of Set 5 | aswan
# Processing Record 11 of Set 5 | hualmay
# Processing Record 12 of Set 5 | qasigiannguit
# Processing Record 13 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 5 | ereymentau
# Processing Record 15 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 5 | chivay
# Processing Record 17 of Set 5 | jieshi
# Processing Record 18 of Set 5 | poum
# Processing Record 19 of Set 5 | caorle
# Processing Record 20 of Set 5 | karratha
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | obera
# Processing Record 23 of Set 5 | darhan
# Processing Record 24 of Set 5 | kijabe
# Processing Record 25 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 5 | ulladulla
# Processing Record 27 of Set 5 | lata
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | bilibino
# Processing Record 30 of Set 5 | yarada
# Processing Record 31 of Set 5 | kaseda
# Processing Record 32 of Set 5 | korla
# Processing Record 33 of Set 5 | salalah
# Processing Record 34 of Set 5 | papara
# Processing Record 35 of Set 5 | daru
# Processing Record 36 of Set 5 | moose factory
# Processing Record 37 of Set 5 | haines junction
# Processing Record 38 of Set 5 | yacuiba
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | mucuri
# Processing Record 41 of Set 5 | takanabe
# Processing Record 42 of Set 5 | castro
# Processing Record 43 of Set 5 | college
# Processing Record 44 of Set 5 | port moresby
# Processing Record 45 of Set 5 | atar
# Processing Record 46 of Set 5 | berlevag
# Processing Record 47 of Set 5 | luderitz
# Processing Record 48 of Set 5 | seymchan
# Processing Record 49 of Set 5 | mecca
# Processing Record 50 of Set 5 | los llanos de aridane
# Processing Record 1 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 6 | kampene
# Processing Record 3 of Set 6 | muros
# Processing Record 4 of Set 6 | barzas
# Processing Record 5 of Set 6 | nongstoin
# Processing Record 6 of Set 6 | georgetown
# Processing Record 7 of Set 6 | ulaangom
# Processing Record 8 of Set 6 | ponta do sol
# Processing Record 9 of Set 6 | noumea
# Processing Record 10 of Set 6 | alice springs
# Processing Record 11 of Set 6 | tautira
# Processing Record 12 of Set 6 | del rio
# Processing Record 13 of Set 6 | khash
# Processing Record 14 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 6 | narsaq
# Processing Record 16 of Set 6 | carandai
# Processing Record 17 of Set 6 | buraydah
# Processing Record 18 of Set 6 | ahipara
# Processing Record 19 of Set 6 | calama
# Processing Record 20 of Set 6 | rocha
# Processing Record 21 of Set 6 | boone
# Processing Record 22 of Set 6 | darnah
# Processing Record 23 of Set 6 | igrim
# Processing Record 24 of Set 6 | bichena
# Processing Record 25 of Set 6 | guaraniacu
# Processing Record 26 of Set 6 | tamandare
# Processing Record 27 of Set 6 | sisimiut
# Processing Record 28 of Set 6 | bogorodskoye
# Processing Record 29 of Set 6 | laguna
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | kawalu
# Processing Record 32 of Set 6 | mino
# Processing Record 33 of Set 6 | terra santa
# Processing Record 34 of Set 6 | aklavik
# Processing Record 35 of Set 6 | mennecy
# Processing Record 36 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 6 | staroye drozhzhanoye
# Processing Record 38 of Set 6 | udachnyy
# Processing Record 39 of Set 6 | lichinga
# Processing Record 40 of Set 6 | itaituba
# Processing Record 41 of Set 6 | brownsville
# Processing Record 42 of Set 6 | ginir
# Processing Record 43 of Set 6 | moanda
# Processing Record 44 of Set 6 | takaungu
# Processing Record 45 of Set 6 | samarai
# Processing Record 46 of Set 6 | port blair
# Processing Record 47 of Set 6 | isiro
# Processing Record 48 of Set 6 | pimenta bueno
# Processing Record 49 of Set 6 | kudahuvadhoo
# Processing Record 50 of Set 6 | lanxi
# Processing Record 1 of Set 7 | lulea
# Processing Record 2 of Set 7 | orasac
# Processing Record 3 of Set 7 | lazaro cardenas
# Processing Record 4 of Set 7 | asau
# Processing Record 5 of Set 7 | broken hill
# Processing Record 6 of Set 7 | vila do maio
# Processing Record 7 of Set 7 | palana
# Processing Record 8 of Set 7 | acapulco
# Processing Record 9 of Set 7 | el alto
# Processing Record 10 of Set 7 | revda
# Processing Record 11 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 7 | antofagasta
# Processing Record 13 of Set 7 | loikaw
# Processing Record 14 of Set 7 | carauari
# Processing Record 15 of Set 7 | pareora
# Processing Record 16 of Set 7 | santa maria
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | pithora
# Processing Record 19 of Set 7 | muisne
# Processing Record 20 of Set 7 | acajutla
# Processing Record 21 of Set 7 | kokoda
# Processing Record 22 of Set 7 | jalu
# Processing Record 23 of Set 7 | bambous virieux
# Processing Record 24 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 25 of Set 7 | qui nhon
# Processing Record 26 of Set 7 | san patricio
# Processing Record 27 of Set 7 | ostrovnoy
# Processing Record 28 of Set 7 | kinshasa
# Processing Record 29 of Set 7 | tapes
# Processing Record 30 of Set 7 | wattegama
# Processing Record 31 of Set 7 | honningsvag
# Processing Record 32 of Set 7 | la palma
# Processing Record 33 of Set 7 | cabo san lucas
# Processing Record 34 of Set 7 | little current
# Processing Record 35 of Set 7 | kholmogory
# Processing Record 36 of Set 7 | yulara
# Processing Record 37 of Set 7 | rocky mount
# Processing Record 38 of Set 7 | eyl
# Processing Record 39 of Set 7 | tambura
# Processing Record 40 of Set 7 | cuamba
# Processing Record 41 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 7 | ovsyanka
# Processing Record 43 of Set 7 | jasper
# Processing Record 44 of Set 7 | avera
# Processing Record 45 of Set 7 | sorong
# Processing Record 46 of Set 7 | cabatuan
# Processing Record 47 of Set 7 | nikolayevsk-na-amure
# Processing Record 48 of Set 7 | batagay
# Processing Record 49 of Set 7 | sao jose da coroa grande
# Processing Record 50 of Set 7 | vire
# Processing Record 1 of Set 8 | jining
# Processing Record 2 of Set 8 | safford
# Processing Record 3 of Set 8 | yarkovo
# Processing Record 4 of Set 8 | rawson
# Processing Record 5 of Set 8 | nuuk
# Processing Record 6 of Set 8 | esso
# Processing Record 7 of Set 8 | te anau
# Processing Record 8 of Set 8 | amudat
# Processing Record 9 of Set 8 | kashi
# Processing Record 10 of Set 8 | ust-charyshskaya pristan
# Processing Record 11 of Set 8 | rizoma
# Processing Record 12 of Set 8 | medicine hat
# Processing Record 13 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 8 | esperance
# Processing Record 15 of Set 8 | derzhavinsk
# Processing Record 16 of Set 8 | poso
# Processing Record 17 of Set 8 | sari
# Processing Record 18 of Set 8 | luang prabang
# Processing Record 19 of Set 8 | aksu
# Processing Record 20 of Set 8 | san quintin
# Processing Record 21 of Set 8 | lushoto
# Processing Record 22 of Set 8 | omboue
# Processing Record 23 of Set 8 | roald
# Processing Record 24 of Set 8 | kommunar
# Processing Record 25 of Set 8 | port-gentil
# Processing Record 26 of Set 8 | nyurba
# Processing Record 27 of Set 8 | touros
# Processing Record 28 of Set 8 | makambako
# Processing Record 29 of Set 8 | praxedis guerrero
# Processing Record 30 of Set 8 | kaeo
# Processing Record 31 of Set 8 | edson
# Processing Record 32 of Set 8 | bethel
# Processing Record 33 of Set 8 | bukachacha
# Processing Record 34 of Set 8 | turbat
# Processing Record 35 of Set 8 | yumen
# Processing Record 36 of Set 8 | uri
# Processing Record 37 of Set 8 | galesong
# Processing Record 38 of Set 8 | flinders
# Processing Record 39 of Set 8 | sabang
# Processing Record 40 of Set 8 | deputatskiy
# Processing Record 41 of Set 8 | macae
# Processing Record 42 of Set 8 | guanica
# Processing Record 43 of Set 8 | ewa beach
# Processing Record 44 of Set 8 | rondonopolis
# Processing Record 45 of Set 8 | shunyi
# Processing Record 46 of Set 8 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 47 of Set 8 | grand gaube
# Processing Record 48 of Set 8 | bafoulabe
# Processing Record 49 of Set 8 | geraldton
# Processing Record 50 of Set 8 | vanimo
# Processing Record 1 of Set 9 | hasaki
# Processing Record 2 of Set 9 | polunochnoye
# Processing Record 3 of Set 9 | randvere
# City not found. Skipping...
# Processing Record 4 of Set 9 | bonavista
# Processing Record 5 of Set 9 | tabas
# Processing Record 6 of Set 9 | otradnoye
# Processing Record 7 of Set 9 | mana
# Processing Record 8 of Set 9 | tiarei
# Processing Record 9 of Set 9 | nelson bay
# Processing Record 10 of Set 9 | baghdad
# Processing Record 11 of Set 9 | baykit
# Processing Record 12 of Set 9 | athabasca
# Processing Record 13 of Set 9 | crailsheim
# Processing Record 14 of Set 9 | ambilobe
# Processing Record 15 of Set 9 | brae
# Processing Record 16 of Set 9 | kirovskiy
# Processing Record 17 of Set 9 | alcaniz
# Processing Record 18 of Set 9 | half moon bay
# Processing Record 19 of Set 9 | mayo
# Processing Record 20 of Set 9 | nogent-le-rotrou
# Processing Record 21 of Set 9 | constantine
# Processing Record 22 of Set 9 | yenagoa
# Processing Record 23 of Set 9 | redwater
# Processing Record 24 of Set 9 | haftoni
# Processing Record 25 of Set 9 | hearst
# Processing Record 26 of Set 9 | russell
# Processing Record 27 of Set 9 | mason city
# Processing Record 28 of Set 9 | sao filipe
# Processing Record 29 of Set 9 | presidente medici
# Processing Record 30 of Set 9 | shimoda
# Processing Record 31 of Set 9 | derby
# Processing Record 32 of Set 9 | pozo colorado
# Processing Record 33 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 9 | vestmannaeyjar
# Processing Record 35 of Set 9 | bay roberts
# Processing Record 36 of Set 9 | faanui
# Processing Record 37 of Set 9 | beloha
# Processing Record 38 of Set 9 | ust-omchug
# Processing Record 39 of Set 9 | maceio
# Processing Record 40 of Set 9 | vryburg
# Processing Record 41 of Set 9 | anadyr
# Processing Record 42 of Set 9 | axixa do tocantins
# City not found. Skipping...
# Processing Record 43 of Set 9 | manono
# Processing Record 44 of Set 9 | tabuk
# Processing Record 45 of Set 9 | baruun-urt
# Processing Record 46 of Set 9 | alofi
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | bandraboua
# Processing Record 49 of Set 9 | matao
# Processing Record 50 of Set 9 | port keats
# Processing Record 1 of Set 10 | nanakuli
# Processing Record 2 of Set 10 | nhulunbuy
# Processing Record 3 of Set 10 | shelburne
# Processing Record 4 of Set 10 | marsa matruh
# Processing Record 5 of Set 10 | gazanjyk
# Processing Record 6 of Set 10 | bukama
# Processing Record 7 of Set 10 | salekhard
# Processing Record 8 of Set 10 | orlik
# Processing Record 9 of Set 10 | havoysund
# Processing Record 10 of Set 10 | chirilagua
# Processing Record 11 of Set 10 | awjilah
# Processing Record 12 of Set 10 | manicore
# Processing Record 13 of Set 10 | vanavara
# Processing Record 14 of Set 10 | onda
# Processing Record 15 of Set 10 | ambatolampy
# Processing Record 16 of Set 10 | ferkessedougou
# Processing Record 17 of Set 10 | copiapo
# Processing Record 18 of Set 10 | doka
# Processing Record 19 of Set 10 | ailigandi
# Processing Record 20 of Set 10 | jiuquan
# Processing Record 21 of Set 10 | beinasco
# Processing Record 22 of Set 10 | olinda
# Processing Record 23 of Set 10 | atbasar
# Processing Record 24 of Set 10 | bambari
# Processing Record 25 of Set 10 | salto
# Processing Record 26 of Set 10 | evensk
# Processing Record 27 of Set 10 | kupang
# Processing Record 28 of Set 10 | wieliczka
# Processing Record 29 of Set 10 | tilichiki
# Processing Record 30 of Set 10 | oranjestad
# Processing Record 31 of Set 10 | chuy
# Processing Record 32 of Set 10 | makinsk
# Processing Record 33 of Set 10 | neuquen
# Processing Record 34 of Set 10 | worthing
# Processing Record 35 of Set 10 | teya
# Processing Record 36 of Set 10 | hamilton
# Processing Record 37 of Set 10 | banda aceh
# Processing Record 38 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 10 | egvekinot
# Processing Record 40 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 10 | moree
# Processing Record 42 of Set 10 | canchungo
# Processing Record 43 of Set 10 | manamadurai
# Processing Record 44 of Set 10 | voi
# Processing Record 45 of Set 10 | matagami
# Processing Record 46 of Set 10 | murud
# Processing Record 47 of Set 10 | strezhevoy
# Processing Record 48 of Set 10 | matara
# Processing Record 49 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 10 | bengkulu
# Processing Record 1 of Set 11 | saurimo
# Processing Record 2 of Set 11 | yangliuqing
# Processing Record 3 of Set 11 | nizhniy baskunchak
# Processing Record 4 of Set 11 | kongsberg
# Processing Record 5 of Set 11 | boden
# Processing Record 6 of Set 11 | diego de almagro
# Processing Record 7 of Set 11 | tigil
# Processing Record 8 of Set 11 | huarmey
# Processing Record 9 of Set 11 | kasongo-lunda
# Processing Record 10 of Set 11 | traralgon
# Processing Record 11 of Set 11 | malinyi
# Processing Record 12 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 13 of Set 11 | kalmunai
# Processing Record 14 of Set 11 | teguldet
# Processing Record 15 of Set 11 | boissevain
# Processing Record 16 of Set 11 | kalengwa
# Processing Record 17 of Set 11 | najran
# Processing Record 18 of Set 11 | srandakan
# Processing Record 19 of Set 11 | shubarshi
# Processing Record 20 of Set 11 | pelym
# Processing Record 21 of Set 11 | mitsamiouli
# Processing Record 22 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 11 | sovetskiy
# Processing Record 24 of Set 11 | bristol
# Processing Record 25 of Set 11 | amapa
# Processing Record 26 of Set 11 | kloulklubed
# Processing Record 27 of Set 11 | arecibo
# Processing Record 28 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 11 | bambanglipuro
# Processing Record 30 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 11 | kamenka
# Processing Record 33 of Set 11 | mogadishu
# Processing Record 34 of Set 11 | codrington
# Processing Record 35 of Set 11 | baculin
# Processing Record 36 of Set 11 | ribeira brava
# Processing Record 37 of Set 11 | yanji
# Processing Record 38 of Set 11 | saint augustine
# Processing Record 39 of Set 11 | bansko
# Processing Record 40 of Set 11 | lesnoye
# Processing Record 41 of Set 11 | beringovskiy
# Processing Record 42 of Set 11 | novoagansk
# Processing Record 43 of Set 11 | ballina
# Processing Record 44 of Set 11 | north bend
# Processing Record 45 of Set 11 | bembereke
# Processing Record 46 of Set 11 | itarema
# Processing Record 47 of Set 11 | sibolga
# Processing Record 48 of Set 11 | kamina
# Processing Record 49 of Set 11 | the pas
# Processing Record 50 of Set 11 | mazamari
# Processing Record 1 of Set 12 | vestmanna
# Processing Record 2 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 12 | foca
# Processing Record 4 of Set 12 | kota tinggi
# Processing Record 5 of Set 12 | majene
# Processing Record 6 of Set 12 | savannah bight
# Processing Record 7 of Set 12 | tuatapere
# Processing Record 8 of Set 12 | dalinghe
# City not found. Skipping...
# Processing Record 9 of Set 12 | nhlangano
# Processing Record 10 of Set 12 | praia
# Processing Record 11 of Set 12 | santiago
# Processing Record 12 of Set 12 | belaya gora
# Processing Record 13 of Set 12 | sorgun
# Processing Record 14 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 15 of Set 12 | walvis bay
# Processing Record 16 of Set 12 | nizhniy kuranakh
# Processing Record 17 of Set 12 | byron bay
# Processing Record 18 of Set 12 | kenmare
# Processing Record 19 of Set 12 | yerbogachen
# Processing Record 20 of Set 12 | sept-iles
# Processing Record 21 of Set 12 | coro
# Processing Record 22 of Set 12 | karlskrona
# Processing Record 23 of Set 12 | ust-kulom
# Processing Record 24 of Set 12 | the valley
# Processing Record 25 of Set 12 | dhidhdhoo
# Processing Record 26 of Set 12 | dolores
# Processing Record 27 of Set 12 | wilmington
# Processing Record 28 of Set 12 | prosec
# Processing Record 29 of Set 12 | camocim
# Processing Record 30 of Set 12 | sao joao da barra
# Processing Record 31 of Set 12 | kulhudhuffushi
# Processing Record 32 of Set 12 | pochutla
# Processing Record 33 of Set 12 | powell river
# Processing Record 34 of Set 12 | assiniboia
# Processing Record 35 of Set 12 | buala
# Processing Record 36 of Set 12 | sambava
# Processing Record 37 of Set 12 | hami
# Processing Record 38 of Set 12 | koroni
# Processing Record 39 of Set 12 | krasnoselkup
# Processing Record 40 of Set 12 | troitsk
# Processing Record 41 of Set 12 | buchanan
# Processing Record 42 of Set 12 | santiago del estero
# Processing Record 43 of Set 12 | moron
# Processing Record 44 of Set 12 | caravelas
# Processing Record 45 of Set 12 | satellite beach
# Processing Record 46 of Set 12 | puerto cortes
# City not found. Skipping...
# Processing Record 47 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 12 | tambun
# Processing Record 49 of Set 12 | necochea
# Processing Record 50 of Set 12 | hobyo
# Processing Record 1 of Set 13 | acari
# Processing Record 2 of Set 13 | tiznit
# Processing Record 3 of Set 13 | srednekolymsk
# Processing Record 4 of Set 13 | sonoita
# Processing Record 5 of Set 13 | dzaoudzi
# Processing Record 6 of Set 13 | davila
# Processing Record 7 of Set 13 | linxia
# Processing Record 8 of Set 13 | lalin
# Processing Record 9 of Set 13 | macas
# Processing Record 10 of Set 13 | niamey
# Processing Record 11 of Set 13 | hailar
# Processing Record 12 of Set 13 | fare
# Processing Record 13 of Set 13 | champerico
# Processing Record 14 of Set 13 | nouadhibou
# Processing Record 15 of Set 13 | bandundu
# Processing Record 16 of Set 13 | guatire
# Processing Record 17 of Set 13 | grande prairie
# Processing Record 18 of Set 13 | pangkalanbuun
# Processing Record 19 of Set 13 | westport
# Processing Record 20 of Set 13 | gombe
# Processing Record 21 of Set 13 | safaga
# Processing Record 22 of Set 13 | bastrop
# Processing Record 23 of Set 13 | kismayo
# Processing Record 24 of Set 13 | marawi
# Processing Record 25 of Set 13 | vikulovo
# Processing Record 26 of Set 13 | talara
# Processing Record 27 of Set 13 | inyonga
# Processing Record 28 of Set 13 | rafaela
# Processing Record 29 of Set 13 | callaguip
# Processing Record 30 of Set 13 | upata
# Processing Record 31 of Set 13 | mutoko
# Processing Record 32 of Set 13 | suoyarvi
# Processing Record 33 of Set 13 | soc trang
# Processing Record 34 of Set 13 | munsingen
# Processing Record 35 of Set 13 | praya
# Processing Record 36 of Set 13 | flin flon
# Processing Record 37 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 38 of Set 13 | adrar
# Processing Record 39 of Set 13 | mount isa
# Processing Record 40 of Set 13 | cockburn town
# Processing Record 41 of Set 13 | bubaque
# Processing Record 42 of Set 13 | tayu
# Processing Record 43 of Set 13 | buta
# Processing Record 44 of Set 13 | henzada
# City not found. Skipping...
# Processing Record 45 of Set 13 | suntar
# Processing Record 46 of Set 13 | hofn
# Processing Record 47 of Set 13 | cap-aux-meules
# Processing Record 48 of Set 13 | smithers
# Processing Record 49 of Set 13 | tchibanga
# Processing Record 50 of Set 13 | margate
# Processing Record 1 of Set 14 | freetown
# Processing Record 2 of Set 14 | garissa
# Processing Record 3 of Set 14 | coahuayana
# Processing Record 4 of Set 14 | pires do rio
# Processing Record 5 of Set 14 | bela vista do paraiso
# Processing Record 6 of Set 14 | ambon
# Processing Record 7 of Set 14 | ngorongoro
# Processing Record 8 of Set 14 | panaba
# Processing Record 9 of Set 14 | malanville
# Processing Record 10 of Set 14 | battle creek
# Processing Record 11 of Set 14 | sao felix do xingu
# Processing Record 12 of Set 14 | nemuro
# Processing Record 13 of Set 14 | taltal
# Processing Record 14 of Set 14 | tynda
# Processing Record 15 of Set 14 | piacabucu
# Processing Record 16 of Set 14 | gobabis
# Processing Record 17 of Set 14 | hovd
# Processing Record 18 of Set 14 | saravena
# Processing Record 19 of Set 14 | pangai
# Processing Record 20 of Set 14 | klaksvik
# Processing Record 21 of Set 14 | kuching
# Processing Record 22 of Set 14 | kang
# Processing Record 23 of Set 14 | camana
# Processing Record 24 of Set 14 | opuwo
# Processing Record 25 of Set 14 | mayumba
# Processing Record 26 of Set 14 | seoul
# Processing Record 27 of Set 14 | sembe
# Processing Record 28 of Set 14 | butterworth
# Processing Record 29 of Set 14 | komsomolskiy
# Processing Record 30 of Set 14 | sur
# Processing Record 31 of Set 14 | envira
# Processing Record 32 of Set 14 | montijo
# Processing Record 33 of Set 14 | nema
# Processing Record 34 of Set 14 | leningradskiy
# Processing Record 35 of Set 14 | broome
# Processing Record 36 of Set 14 | santa rosa
# Processing Record 37 of Set 14 | gopalpur
# Processing Record 38 of Set 14 | havelock
# Processing Record 39 of Set 14 | williams lake
# Processing Record 40 of Set 14 | ejido
# Processing Record 41 of Set 14 | paamiut
# Processing Record 42 of Set 14 | somotillo
# Processing Record 43 of Set 14 | christchurch
# Processing Record 44 of Set 14 | ous
# Processing Record 45 of Set 14 | kikuchi
# Processing Record 46 of Set 14 | kayes
# Processing Record 47 of Set 14 | hun
# Processing Record 48 of Set 14 | haizhou
# Processing Record 49 of Set 14 | sabla
# Processing Record 50 of Set 14 | algodones
# Processing Record 1 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 2 of Set 15 | pampas
# Processing Record 3 of Set 15 | ngunguru
# Processing Record 4 of Set 15 | tutoia
# Processing Record 5 of Set 15 | longyan
# Processing Record 6 of Set 15 | uslar
# Processing Record 7 of Set 15 | baoning
# Processing Record 8 of Set 15 | irtyshskiy
# Processing Record 9 of Set 15 | champasak
# Processing Record 10 of Set 15 | khovu-aksy
# Processing Record 11 of Set 15 | riyadh
# Processing Record 12 of Set 15 | khor
# Processing Record 13 of Set 15 | glenluce
# Processing Record 14 of Set 15 | luau
# Processing Record 15 of Set 15 | vilhena
# Processing Record 16 of Set 15 | santa isabel do rio negro
# Processing Record 17 of Set 15 | pringsewu
# Processing Record 18 of Set 15 | mahibadhoo
# Processing Record 19 of Set 15 | pemangkat
# Processing Record 20 of Set 15 | kangaatsiaq
# Processing Record 21 of Set 15 | kysyl-syr
# Processing Record 22 of Set 15 | coxim
# Processing Record 23 of Set 15 | sibu
# Processing Record 24 of Set 15 | kleck
# City not found. Skipping...
# Processing Record 25 of Set 15 | skarzysko-kamienna
# Processing Record 26 of Set 15 | yantongshan
# Processing Record 27 of Set 15 | portland
# Processing Record 28 of Set 15 | aizpute
# Processing Record 29 of Set 15 | ponta delgada
# Processing Record 30 of Set 15 | dukat
# Processing Record 31 of Set 15 | pascagoula
# Processing Record 32 of Set 15 | kieta
# Processing Record 33 of Set 15 | ishigaki
# Processing Record 34 of Set 15 | iquique
# Processing Record 35 of Set 15 | kushima
# Processing Record 36 of Set 15 | izhma
# Processing Record 37 of Set 15 | dankov
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 687

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     54.05        74         100
# 1         Bluff      NZ -46.6000  168.3333     50.81        88         100
# 2  Batemans Bay      AU -35.7167  150.1833     51.10        87         100
# 3        Nurota      UZ  40.5614   65.6886     39.29        41           0
# 4         Cumra      TR  37.5732   32.7745     64.54        22           0
# 5  Longyearbyen      SJ  78.2186   15.6401     21.04        79          20
# 6      Coquimbo      CL -29.9533  -71.3436     65.93        39           0
# 7        Barrow      US  71.2906 -156.7887     28.42        80          90
# 8       Mataura      NZ -46.1927  168.8643     50.49        82         100
# 9       Naqadeh      IR  36.9553   45.3880     55.36        47           0
#
#    Wind Speed Current Description
# 0       11.45     overcast clouds
# 1        8.12     overcast clouds
# 2        6.51     overcast clouds
# 3        3.53           clear sky
# 4        2.53           clear sky
# 5        8.05          few clouds
# 6       14.97           clear sky
# 7       10.36     overcast clouds
# 8        1.14          light rain
# 9        1.79           clear sky

# %%
city_data_df["Lat"] = pd.to_numeric(city_data_df["Lat"], downcast="float")
city_data_df["Lng"] = pd.to_numeric(city_data_df["Lng"], downcast="float")

# %%
city_data_df["Lat"]=city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"]=city_data_df["Lng"].map("{:.2f}".format)

# %%
city_data_df.head(10)
# Out:
#            City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU  -33.65   115.33     54.05        74         100
# 1         Bluff      NZ  -46.60   168.33     50.81        88         100
# 2  Batemans Bay      AU  -35.72   150.18     51.10        87         100
# 3        Nurota      UZ   40.56    65.69     39.29        41           0
# 4         Cumra      TR   37.57    32.77     64.54        22           0
# 5  Longyearbyen      SJ   78.22    15.64     21.04        79          20
# 6      Coquimbo      CL  -29.95   -71.34     65.93        39           0
# 7        Barrow      US   71.29  -156.79     28.42        80          90
# 8       Mataura      NZ  -46.19   168.86     50.49        82         100
# 9       Naqadeh      IR   36.96    45.39     55.36        47           0
#
#    Wind Speed Current Description
# 0       11.45     overcast clouds
# 1        8.12     overcast clouds
# 2        6.51     overcast clouds
# 3        3.53           clear sky
# 4        2.53           clear sky
# 5        8.05          few clouds
# 6       14.97           clear sky
# 7       10.36     overcast clouds
# 8        1.14          light rain
# 9        1.79           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df
# Out:
#              City Country     Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU  -33.65  115.33     54.05        74         100
# 1           Bluff      NZ  -46.60  168.33     50.81        88         100
# 2    Batemans Bay      AU  -35.72  150.18     51.10        87         100
# 3          Nurota      UZ   40.56   65.69     39.29        41           0
# 4           Cumra      TR   37.57   32.77     64.54        22           0
# ..            ...     ...     ...     ...       ...       ...         ...
# 682      Ishigaki      JP   24.34  124.16     81.23        83         100
# 683       Iquique      CL  -20.22  -70.14     62.64        69          33
# 684       Kushima      JP   31.46  131.23     78.12        93          27
# 685         Izhma      RU   65.01   53.91     31.96        96         100
# 686        Dankov      RU   53.25   39.16     40.35        57          13
#
#      Wind Speed Current Description
# 0         11.45     overcast clouds
# 1          8.12     overcast clouds
# 2          6.51     overcast clouds
# 3          3.53           clear sky
# 4          2.53           clear sky
# ..          ...                 ...
# 682       31.90     overcast clouds
# 683        9.04    scattered clouds
# 684        3.65    scattered clouds
# 685       10.29                snow
# 686        1.50          few clouds
#
# [687 rows x 9 columns]
